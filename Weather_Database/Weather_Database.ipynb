# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
#Create two arrays of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
#zipping them
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
   city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

   # If the city is unique, then we will add it to the cities list.
   if city not in cities:
       cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# build the basic URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    #   we are removing the blank spaces in 
    #   the city name and concatenating the city name with '+'
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list with a dictionary for that city.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as ex:
        print(ex)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 50 of Set 71 | pisco
# Processing Record 51 of Set 71 | katobu
# Processing Record 52 of Set 71 | constitucion
# Processing Record 53 of Set 71 | ponta do sol
# Processing Record 54 of Set 71 | labuhan
# Processing Record 55 of Set 71 | puerto ayora
# Processing Record 56 of Set 71 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 57 of Set 71 | saskylakh
# Processing Record 58 of Set 71 | moree
# Processing Record 59 of Set 71 | kaitangata
# Processing Record 60 of Set 71 | penzance
# Processing Record 61 of Set 71 | tuktoyaktuk
# Processing Record 62 of Set 71 | hermanus
# Processing Record 63 of Set 71 | vaini
# Processing Record 64 of Set 71 | jamestown
# Processing Record 65 of Set 71 | durango
# Processing Record 66 of Set 71 | pahrump
# Processing Record 67 of Set 71 | georgetown
# Processing Record 68 of Set 71 | bengkulu
# Processing Record 69 of Set 71 | jiwani
# Processing Record 70 of Set 71 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 71 of Set 71 | east london
# Processing Record 72 of Set 71 | grindavik
# Processing Record 73 of Set 71 | provideniya
# Processing Record 74 of Set 71 | najran
# Processing Record 75 of Set 71 | gravdal
# Processing Record 76 of Set 71 | hobart
# Processing Record 77 of Set 71 | utiroa
# 'coord'
# City not found. Skipping...
# Processing Record 78 of Set 71 | tomatlan
# Processing Record 79 of Set 71 | quatre cocos
# Processing Record 80 of Set 71 | ushuaia
# Processing Record 81 of Set 71 | kegayli
# 'coord'
# City not found. Skipping...
# Processing Record 82 of Set 71 | tabursuq
# Processing Record 83 of Set 71 | palmer
# Processing Record 84 of Set 71 | pevek
# Processing Record 85 of Set 71 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 86 of Set 71 | mecca
# Processing Record 87 of Set 71 | busselton
# Processing Record 88 of Set 71 | karkaralinsk
# 'coord'
# City not found. Skipping...
# Processing Record 89 of Set 71 | yellowknife
# Processing Record 90 of Set 71 | rikitea
# Processing Record 91 of Set 71 | punta arenas
# Processing Record 92 of Set 71 | mar del plata
# Processing Record 93 of Set 71 | lowestoft
# Processing Record 94 of Set 71 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 95 of Set 71 | bredasdorp
# Processing Record 96 of Set 71 | lumphat
# Processing Record 97 of Set 71 | los llanos de aridane
# Processing Record 98 of Set 71 | mangrol
# Processing Record 99 of Set 71 | caravelas
# Processing Record 1 of Set 72 | komsomolskiy
# Processing Record 2 of Set 72 | huilong
# Processing Record 3 of Set 72 | amapa
# Processing Record 4 of Set 72 | mataura
# Processing Record 5 of Set 72 | nikolskoye
# Processing Record 6 of Set 72 | khatanga
# Processing Record 7 of Set 72 | jaipur hat
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 72 | saint george
# Processing Record 9 of Set 72 | huntsville
# Processing Record 10 of Set 72 | asau
# Processing Record 11 of Set 72 | bambous virieux
# Processing Record 12 of Set 72 | albany
# Processing Record 13 of Set 72 | aviles
# Processing Record 14 of Set 72 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 72 | sao filipe
# Processing Record 16 of Set 72 | mount isa
# Processing Record 17 of Set 72 | mongomo
# Processing Record 18 of Set 72 | lebu
# Processing Record 19 of Set 72 | kimberley
# Processing Record 20 of Set 72 | kpandae
# Processing Record 21 of Set 72 | kurikka
# Processing Record 22 of Set 72 | nouadhibou
# Processing Record 23 of Set 72 | toftir
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 72 | caxias
# Processing Record 25 of Set 72 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 72 | qui nhon
# Processing Record 27 of Set 72 | trelew
# Processing Record 28 of Set 72 | njombe
# Processing Record 29 of Set 72 | victoria
# Processing Record 30 of Set 72 | meulaboh
# Processing Record 31 of Set 72 | cape town
# Processing Record 32 of Set 72 | rio gallegos
# Processing Record 33 of Set 72 | anchorage
# Processing Record 34 of Set 72 | port alfred
# Processing Record 35 of Set 72 | vanimo
# Processing Record 36 of Set 72 | lavrentiya
# Processing Record 37 of Set 72 | avarua
# Processing Record 38 of Set 72 | bouloupari
# Processing Record 39 of Set 72 | saint-philippe
# Processing Record 40 of Set 72 | show low
# Processing Record 41 of Set 72 | klaksvik
# Processing Record 42 of Set 72 | luderitz
# Processing Record 43 of Set 72 | alvorada
# Processing Record 44 of Set 72 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 72 | ahipara
# Processing Record 46 of Set 72 | isangel
# Processing Record 47 of Set 72 | salalah
# Processing Record 48 of Set 72 | dicabisagan
# Processing Record 49 of Set 72 | samoded
# Processing Record 50 of Set 72 | boralday
# Processing Record 1 of Set 73 | mattru
# Processing Record 2 of Set 73 | hithadhoo
# Processing Record 3 of Set 73 | burnie
# Processing Record 4 of Set 73 | aasiaat
# Processing Record 5 of Set 73 | mayo
# Processing Record 6 of Set 73 | hilo
# Processing Record 7 of Set 73 | charters towers
# Processing Record 8 of Set 73 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 73 | thompson
# Processing Record 10 of Set 73 | acapulco
# Processing Record 11 of Set 73 | mahebourg
# Processing Record 12 of Set 73 | ambovombe
# Processing Record 13 of Set 73 | bethel
# Processing Record 14 of Set 73 | santa maria
# Processing Record 15 of Set 73 | santa cruz de tenerife
# Processing Record 16 of Set 73 | port hawkesbury
# Processing Record 17 of Set 73 | mahon
# Processing Record 18 of Set 73 | qaanaaq
# Processing Record 19 of Set 73 | honiara
# Processing Record 20 of Set 73 | kapaa
# Processing Record 21 of Set 73 | ancud
# Processing Record 22 of Set 73 | porto novo
# Processing Record 23 of Set 73 | walvis bay
# Processing Record 24 of Set 73 | leningradskiy
# Processing Record 25 of Set 73 | ambulu
# Processing Record 26 of Set 73 | zlatoustovsk
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 73 | katherine
# Processing Record 28 of Set 73 | port hedland
# Processing Record 29 of Set 73 | misratah
# Processing Record 30 of Set 73 | diego de almagro
# Processing Record 31 of Set 73 | kismayo
# Processing Record 32 of Set 73 | carnarvon
# Processing Record 33 of Set 73 | ilmenau
# Processing Record 34 of Set 73 | lasa
# Processing Record 35 of Set 73 | kishi
# Processing Record 36 of Set 73 | alyangula
# Processing Record 37 of Set 73 | chokurdakh
# Processing Record 38 of Set 73 | kavieng
# Processing Record 39 of Set 73 | jiangkou
# Processing Record 40 of Set 73 | zhanatas
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 73 | college
# Processing Record 42 of Set 73 | vao
# Processing Record 43 of Set 73 | tasiilaq
# Processing Record 44 of Set 73 | nishihara
# Processing Record 45 of Set 73 | torbay
# Processing Record 46 of Set 73 | hami
# Processing Record 47 of Set 73 | kavaratti
# Processing Record 48 of Set 73 | barguzin
# Processing Record 49 of Set 73 | cidreira
# Processing Record 50 of Set 73 | havre-saint-pierre
# Processing Record 1 of Set 74 | severo-kurilsk
# Processing Record 2 of Set 74 | batemans bay
# Processing Record 3 of Set 74 | broken hill
# Processing Record 4 of Set 74 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 74 | atuona
# Processing Record 6 of Set 74 | butaritari
# Processing Record 7 of Set 74 | tura
# Processing Record 8 of Set 74 | calabozo
# Processing Record 9 of Set 74 | punta alta
# Processing Record 10 of Set 74 | rawson
# Processing Record 11 of Set 74 | korla
# Processing Record 12 of Set 74 | almaznyy
# Processing Record 13 of Set 74 | jiangyou
# Processing Record 14 of Set 74 | san andres
# Processing Record 15 of Set 74 | souillac
# Processing Record 16 of Set 74 | humboldt
# Processing Record 17 of Set 74 | ribeira grande
# Processing Record 18 of Set 74 | port elizabeth
# Processing Record 19 of Set 74 | yumen
# Processing Record 20 of Set 74 | mezen
# Processing Record 21 of Set 74 | coquimbo
# Processing Record 22 of Set 74 | mandalgovi
# Processing Record 23 of Set 74 | kuala terengganu
# Processing Record 24 of Set 74 | uwayl
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 74 | kardla
# Processing Record 26 of Set 74 | prince rupert
# Processing Record 27 of Set 74 | kodiak
# Processing Record 28 of Set 74 | alice springs
# Processing Record 29 of Set 74 | umm jarr
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 74 | barrow
# Processing Record 31 of Set 74 | rumphi
# Processing Record 32 of Set 74 | boquira
# Processing Record 33 of Set 74 | namibe
# Processing Record 34 of Set 74 | bad gandersheim
# Processing Record 35 of Set 74 | sorong
# Processing Record 36 of Set 74 | necochea
# Processing Record 37 of Set 74 | correntina
# Processing Record 38 of Set 74 | lata
# Processing Record 39 of Set 74 | stornoway
# Processing Record 40 of Set 74 | kruisfontein
# Processing Record 41 of Set 74 | manggar
# Processing Record 42 of Set 74 | monrovia
# Processing Record 43 of Set 74 | laguna
# Processing Record 44 of Set 74 | airai
# Processing Record 45 of Set 74 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 74 | damghan
# Processing Record 47 of Set 74 | bluff
# Processing Record 48 of Set 74 | baytown
# Processing Record 49 of Set 74 | upernavik
# Processing Record 50 of Set 74 | marienburg
# Processing Record 1 of Set 75 | nanortalik
# Processing Record 2 of Set 75 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 75 | esperance
# Processing Record 4 of Set 75 | mananjary
# Processing Record 5 of Set 75 | verkhniy landekh
# Processing Record 6 of Set 75 | lakatoro
# Processing Record 7 of Set 75 | keshan
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 75 | ostrovnoy
# Processing Record 9 of Set 75 | lompoc
# Processing Record 10 of Set 75 | taksimo
# Processing Record 11 of Set 75 | nome
# Processing Record 12 of Set 75 | shimoda
# Processing Record 13 of Set 75 | harper
# Processing Record 14 of Set 75 | can
# Processing Record 15 of Set 75 | kungurtug
# Processing Record 16 of Set 75 | balarampur
# Processing Record 17 of Set 75 | yarada
# Processing Record 18 of Set 75 | xuanhua
# Processing Record 19 of Set 75 | broome
# Processing Record 20 of Set 75 | akdepe
# Processing Record 21 of Set 75 | hay river
# Processing Record 22 of Set 75 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 75 | vila franca do campo
# Processing Record 24 of Set 75 | wooster
# Processing Record 25 of Set 75 | dikson
# Processing Record 26 of Set 75 | new richmond
# Processing Record 27 of Set 75 | tarko-sale
# Processing Record 28 of Set 75 | mahanoro
# Processing Record 29 of Set 75 | abu dhabi
# Processing Record 30 of Set 75 | sao desiderio
# Processing Record 31 of Set 75 | cayenne
# Processing Record 32 of Set 75 | saint-joseph
# Processing Record 33 of Set 75 | castro
# Processing Record 34 of Set 75 | stromness
# Processing Record 35 of Set 75 | ishigaki
# Processing Record 36 of Set 75 | beira
# Processing Record 37 of Set 75 | nedjo
# Processing Record 38 of Set 75 | sundsvall
# Processing Record 39 of Set 75 | aflu
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 75 | hasaki
# Processing Record 41 of Set 75 | longyearbyen
# Processing Record 42 of Set 75 | fortuna
# Processing Record 43 of Set 75 | dickinson
# Processing Record 44 of Set 75 | konya
# Processing Record 45 of Set 75 | the valley
# Processing Record 46 of Set 75 | cabo san lucas
# Processing Record 47 of Set 75 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 75 | oksfjord
# Processing Record 49 of Set 75 | xiamen
# Processing Record 50 of Set 75 | poum
# Processing Record 1 of Set 76 | saldus
# Processing Record 2 of Set 76 | lagoa
# Processing Record 3 of Set 76 | kirksville
# Processing Record 4 of Set 76 | griffith
# Processing Record 5 of Set 76 | jijiga
# Processing Record 6 of Set 76 | san patricio
# Processing Record 7 of Set 76 | champerico
# Processing Record 8 of Set 76 | richards bay
# Processing Record 9 of Set 76 | hamilton
# Processing Record 10 of Set 76 | bechem
# Processing Record 11 of Set 76 | hargeysa
# Processing Record 12 of Set 76 | dukat
# Processing Record 13 of Set 76 | yabrud
# Processing Record 14 of Set 76 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 76 | nakusp
# Processing Record 16 of Set 76 | belmonte
# Processing Record 17 of Set 76 | kalianget
# Processing Record 18 of Set 76 | yulara
# Processing Record 19 of Set 76 | iqaluit
# Processing Record 20 of Set 76 | luau
# Processing Record 21 of Set 76 | pallasovka
# Processing Record 22 of Set 76 | mount pleasant
# Processing Record 23 of Set 76 | new norfolk
# Processing Record 24 of Set 76 | bilma
# Processing Record 25 of Set 76 | tautira
# Processing Record 26 of Set 76 | chokwe
# Processing Record 27 of Set 76 | kostomuksha
# Processing Record 28 of Set 76 | sid
# Processing Record 29 of Set 76 | chara
# Processing Record 30 of Set 76 | geraldton
# Processing Record 31 of Set 76 | surubim
# Processing Record 32 of Set 76 | mutsamudu
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 76 | yar-sale
# Processing Record 34 of Set 76 | vitim
# Processing Record 35 of Set 76 | dhone
# Processing Record 36 of Set 76 | khandbari
# Processing Record 37 of Set 76 | vanderhoof
# Processing Record 38 of Set 76 | bereda
# Processing Record 39 of Set 76 | tateyama
# Processing Record 40 of Set 76 | noumea
# Processing Record 41 of Set 76 | zaozhuang
# Processing Record 42 of Set 76 | maniitsoq
# Processing Record 43 of Set 76 | khaga
# Processing Record 44 of Set 76 | tuatapere
# Processing Record 45 of Set 76 | mao
# Processing Record 46 of Set 76 | padang
# Processing Record 47 of Set 76 | sahibganj
# Processing Record 48 of Set 76 | bagan
# Processing Record 49 of Set 76 | comodoro rivadavia
# Processing Record 50 of Set 76 | nyurba
# Processing Record 1 of Set 77 | may pen
# Processing Record 2 of Set 77 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 77 | bonanza
# Processing Record 4 of Set 77 | waingapu
# Processing Record 5 of Set 77 | bidor
# Processing Record 6 of Set 77 | huancavelica
# Processing Record 7 of Set 77 | dhidhdhoo
# Processing Record 8 of Set 77 | labutta
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 77 | figeac
# Processing Record 10 of Set 77 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 77 | coaldale
# Processing Record 12 of Set 77 | znamenskoye
# Processing Record 13 of Set 77 | okha
# Processing Record 14 of Set 77 | alexandria
# Processing Record 15 of Set 77 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 77 | lixourion
# Processing Record 17 of Set 77 | sorland
# Processing Record 18 of Set 77 | touros
# Processing Record 19 of Set 77 | lashio
# Processing Record 20 of Set 77 | biltine
# Processing Record 21 of Set 77 | shenjiamen
# Processing Record 22 of Set 77 | cap-aux-meules
# Processing Record 23 of Set 77 | kattivakkam
# Processing Record 24 of Set 77 | tandil
# Processing Record 25 of Set 77 | cockburn harbour
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 77 | kyaukse
# Processing Record 27 of Set 77 | portland
# Processing Record 28 of Set 77 | camacha
# Processing Record 29 of Set 77 | polunochnoye
# Processing Record 30 of Set 77 | fort-shevchenko
# Processing Record 31 of Set 77 | mokhsogollokh
# Processing Record 32 of Set 77 | guiglo
# Processing Record 33 of Set 77 | maceio
# Processing Record 34 of Set 77 | anadyr
# Processing Record 35 of Set 77 | otofuke
# Processing Record 36 of Set 77 | moche
# Processing Record 37 of Set 77 | alghero
# Processing Record 38 of Set 77 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 77 | norman wells
# Processing Record 40 of Set 77 | alofi
# Processing Record 41 of Set 77 | green river
# Processing Record 42 of Set 77 | husavik
# Processing Record 43 of Set 77 | cabedelo
# Processing Record 44 of Set 77 | berdigestyakh
# Processing Record 45 of Set 77 | ilulissat
# Processing Record 46 of Set 77 | tessalit
# Processing Record 47 of Set 77 | huarmey
# Processing Record 48 of Set 77 | struthers
# Processing Record 49 of Set 77 | tiksi
# Processing Record 50 of Set 77 | aleksandrovskaya
# Processing Record 1 of Set 78 | birao
# Processing Record 2 of Set 78 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 78 | guerrero negro
# Processing Record 4 of Set 78 | dzilam gonzalez
# Processing Record 5 of Set 78 | escarcega
# Processing Record 6 of Set 78 | mogadishu
# Processing Record 7 of Set 78 | ojinaga
# Processing Record 8 of Set 78 | tunduru
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 78 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 78 | kalmunai
# Processing Record 11 of Set 78 | moose jaw
# Processing Record 12 of Set 78 | vardo
# Processing Record 13 of Set 78 | cururupu
# Processing Record 14 of Set 78 | chuy
# Processing Record 15 of Set 78 | ukiah
# Processing Record 16 of Set 78 | kathu
# Processing Record 17 of Set 78 | saldanha
# Processing Record 18 of Set 78 | treinta y tres
# Processing Record 19 of Set 78 | mount gambier
# Processing Record 20 of Set 78 | konstantinovka
# Processing Record 21 of Set 78 | srednekolymsk
# Processing Record 22 of Set 78 | maur
# Processing Record 23 of Set 78 | grand gaube
# Processing Record 24 of Set 78 | christchurch
# Processing Record 25 of Set 78 | telenesti
# Processing Record 26 of Set 78 | tahta
# Processing Record 27 of Set 78 | leninogorsk
# Processing Record 28 of Set 78 | bondo
# Processing Record 29 of Set 78 | chino valley
# Processing Record 30 of Set 78 | viedma
# Processing Record 31 of Set 78 | roald
# Processing Record 32 of Set 78 | pacific grove
# Processing Record 33 of Set 78 | tupik
# Processing Record 34 of Set 78 | margherita di savoia
# Processing Record 35 of Set 78 | samagaltay
# Processing Record 36 of Set 78 | faanui
# Processing Record 37 of Set 78 | betare oya
# Processing Record 38 of Set 78 | atasu
# Processing Record 39 of Set 78 | khagrachari
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 78 | barra do garcas
# Processing Record 41 of Set 78 | cabo rojo
# Processing Record 42 of Set 78 | novyy urengoy
# Processing Record 43 of Set 78 | agadez
# Processing Record 44 of Set 78 | cockburn town
# Processing Record 45 of Set 78 | qasigiannguit
# Processing Record 46 of Set 78 | carlsbad
# Processing Record 47 of Set 78 | eyrarbakki
# Processing Record 48 of Set 78 | barinas
# Processing Record 49 of Set 78 | herat
# Processing Record 50 of Set 78 | nemuro
# Processing Record 1 of Set 79 | fort nelson
# Processing Record 2 of Set 79 | pochutla
# Processing Record 3 of Set 79 | shasta lake
# Processing Record 4 of Set 79 | lodja
# Processing Record 5 of Set 79 | tuim
# Processing Record 6 of Set 79 | beringovskiy
# Processing Record 7 of Set 79 | talnakh
# Processing Record 8 of Set 79 | tongzi
# Processing Record 9 of Set 79 | kuruman
# Processing Record 10 of Set 79 | mizan teferi
# Processing Record 11 of Set 79 | crotone
# Processing Record 12 of Set 79 | turukhansk
# Processing Record 13 of Set 79 | sovetskaya gavan
# Processing Record 14 of Set 79 | solnechnyy
# Processing Record 15 of Set 79 | malanje
# Processing Record 16 of Set 79 | katsuura
# Processing Record 17 of Set 79 | sibolga
# Processing Record 18 of Set 79 | half moon bay
# Processing Record 19 of Set 79 | keffi
# Processing Record 20 of Set 79 | illapel
# Processing Record 21 of Set 79 | dunedin
# Processing Record 22 of Set 79 | deputatskiy
# Processing Record 23 of Set 79 | mehran
# Processing Record 24 of Set 79 | nouakchott
# Processing Record 25 of Set 79 | santiago del estero
# Processing Record 26 of Set 79 | te anau
# Processing Record 27 of Set 79 | sept-iles
# Processing Record 28 of Set 79 | sao felix do xingu
# Processing Record 29 of Set 79 | mana
# Processing Record 30 of Set 79 | olafsvik
# Processing Record 31 of Set 79 | itarema
# Processing Record 32 of Set 79 | ranot
# Processing Record 33 of Set 79 | morant bay
# Processing Record 34 of Set 79 | sinnar
# Processing Record 35 of Set 79 | sinnamary
# Processing Record 36 of Set 79 | zelenogorskiy
# Processing Record 37 of Set 79 | pangnirtung
# Processing Record 38 of Set 79 | fairbanks
# Processing Record 39 of Set 79 | benin
# Processing Record 40 of Set 79 | maposeni
# Processing Record 41 of Set 79 | samarai
# Processing Record 42 of Set 79 | xining
# Processing Record 43 of Set 79 | arraial do cabo
# Processing Record 44 of Set 79 | dhangadhi
# Processing Record 45 of Set 79 | salamanca
# Processing Record 46 of Set 79 | sivas
# Processing Record 47 of Set 79 | miles city
# Processing Record 48 of Set 79 | tara
# Processing Record 49 of Set 79 | maragogi
# Processing Record 50 of Set 79 | berlevag
# Processing Record 1 of Set 80 | balkanabat
# Processing Record 2 of Set 80 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 80 | lima
# Processing Record 4 of Set 80 | gobabis
# Processing Record 5 of Set 80 | victoria point
# Processing Record 6 of Set 80 | oranjemund
# Processing Record 7 of Set 80 | henties bay
# Processing Record 8 of Set 80 | dalmatovo
# Processing Record 9 of Set 80 | nioro
# Processing Record 10 of Set 80 | bathsheba
# Processing Record 11 of Set 80 | kaduy
# Processing Record 12 of Set 80 | tuy hoa
# Processing Record 13 of Set 80 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 80 | batagay-alyta
# Processing Record 15 of Set 80 | jizan
# Processing Record 16 of Set 80 | tabou
# Processing Record 17 of Set 80 | nador
# Processing Record 18 of Set 80 | newton
# Processing Record 19 of Set 80 | serebryanyy bor
# Processing Record 20 of Set 80 | finnsnes
# Processing Record 21 of Set 80 | zmievka
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 80 | menongue
# Processing Record 23 of Set 80 | mindelo
# Processing Record 24 of Set 80 | khargone
# Processing Record 25 of Set 80 | wau
# Processing Record 26 of Set 80 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 80 | amarkantak
# Processing Record 28 of Set 80 | hervey bay
# Processing Record 29 of Set 80 | leh
# Processing Record 30 of Set 80 | ibung
# Processing Record 31 of Set 80 | bacuit
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 80 | san rafael
# Processing Record 33 of Set 80 | japura
# Processing Record 34 of Set 80 | harstad
# Processing Record 35 of Set 80 | brownsville
# Processing Record 36 of Set 80 | eyl
# Processing Record 37 of Set 80 | progreso
# Processing Record 38 of Set 80 | tupancireta
# Processing Record 39 of Set 80 | elizabeth city
# Processing Record 40 of Set 80 | clyde river
# Processing Record 41 of Set 80 | basco
# Processing Record 42 of Set 80 | tarakan
# Processing Record 43 of Set 80 | port blair
# Processing Record 44 of Set 80 | koungheul
# Processing Record 45 of Set 80 | iquitos
# Processing Record 46 of Set 80 | la ronge
# Processing Record 47 of Set 80 | karasburg
# Processing Record 48 of Set 80 | tezu
# Processing Record 49 of Set 80 | nushki
# Processing Record 50 of Set 80 | along
# Processing Record 1 of Set 81 | biu
# Processing Record 2 of Set 81 | aklavik
# Processing Record 3 of Set 81 | teguldet
# Processing Record 4 of Set 81 | tevaitoa
# Processing Record 5 of Set 81 | kilindoni
# Processing Record 6 of Set 81 | barcelona
# Processing Record 7 of Set 81 | ust-kuyga
# Processing Record 8 of Set 81 | presidencia roque saenz pena
# Processing Record 9 of Set 81 | otradinskiy
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 81 | bud
# Processing Record 11 of Set 81 | saint-pacome
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 81 | kamenka
# Processing Record 13 of Set 81 | amambai
# Processing Record 14 of Set 81 | dwarka
# Processing Record 15 of Set 81 | lorengau
# Processing Record 16 of Set 81 | kenai
# Processing Record 17 of Set 81 | khash
# Processing Record 18 of Set 81 | bacolod
# Processing Record 19 of Set 81 | novikovo
# Processing Record 20 of Set 81 | natal
# Processing Record 21 of Set 81 | avanigadda
# Processing Record 22 of Set 81 | lazaro cardenas
# Processing Record 23 of Set 81 | alotau
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 81 | cap malheureux
# Processing Record 25 of Set 81 | banda aceh
# Processing Record 26 of Set 81 | ushtobe
# Processing Record 27 of Set 81 | concordia
# Processing Record 28 of Set 81 | yuryevets
# Processing Record 29 of Set 81 | angoche
# ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# City not found. Skipping...
# Processing Record 30 of Set 81 | kaeo
# Processing Record 31 of Set 81 | chapais
# Processing Record 32 of Set 81 | sawakin
# Processing Record 33 of Set 81 | san vicente
# Processing Record 34 of Set 81 | molepolole
# Processing Record 35 of Set 81 | itoman
# Processing Record 36 of Set 81 | aykhal
# Processing Record 37 of Set 81 | toktogul
# Processing Record 38 of Set 81 | new ulm
# Processing Record 39 of Set 81 | narsaq
# Processing Record 40 of Set 81 | raudeberg
# Processing Record 41 of Set 81 | oriximina
# Processing Record 42 of Set 81 | borzya
# Processing Record 43 of Set 81 | arrecife
# Processing Record 44 of Set 81 | magdagachi
# Processing Record 45 of Set 81 | crib point
# Processing Record 46 of Set 81 | artyk
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 81 | buta
# Processing Record 48 of Set 81 | okhotsk
# Processing Record 49 of Set 81 | sitka
# Processing Record 50 of Set 81 | bintulu
# Processing Record 1 of Set 82 | nanakuli
# Processing Record 2 of Set 82 | northam
# Processing Record 3 of Set 82 | ghanzi
# Processing Record 4 of Set 82 | langsa
# Processing Record 5 of Set 82 | evanston
# Processing Record 6 of Set 82 | yurimaguas
# Processing Record 7 of Set 82 | ennis
# Processing Record 8 of Set 82 | puerto escondido
# Processing Record 9 of Set 82 | poronaysk
# Processing Record 10 of Set 82 | yabelo
# Processing Record 11 of Set 82 | hazaribag
# Processing Record 12 of Set 82 | ko samui
# Processing Record 13 of Set 82 | wanlaweyn
# Processing Record 14 of Set 82 | san antonio
# Processing Record 15 of Set 82 | filadelfia
# Processing Record 16 of Set 82 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 82 | bell ville
# Processing Record 18 of Set 82 | tigil
# Processing Record 19 of Set 82 | krasnogvardeyskoye
# Processing Record 20 of Set 82 | hurghada
# Processing Record 21 of Set 82 | byron bay
# Processing Record 22 of Set 82 | jumla
# Processing Record 23 of Set 82 | katete
# Processing Record 24 of Set 82 | nikolayevka
# Processing Record 25 of Set 82 | bredy
# Processing Record 26 of Set 82 | sturgeon falls
# Processing Record 27 of Set 82 | calama
# Processing Record 28 of Set 82 | matam
# Processing Record 29 of Set 82 | osypenko
# Processing Record 30 of Set 82 | chimbote
# Processing Record 31 of Set 82 | bosaso
# Processing Record 32 of Set 82 | vila velha
# Processing Record 33 of Set 82 | shestakovo
# Processing Record 34 of Set 82 | nhulunbuy
# Processing Record 35 of Set 82 | alice town
# Processing Record 36 of Set 82 | talcahuano
# Processing Record 37 of Set 82 | san cristobal
# Processing Record 38 of Set 82 | rudnogorsk
# Processing Record 39 of Set 82 | zongolica
# Processing Record 40 of Set 82 | cherskiy
# Processing Record 41 of Set 82 | chumikan
# Processing Record 42 of Set 82 | cukai
# Processing Record 43 of Set 82 | elko
# Processing Record 44 of Set 82 | morehead
# Processing Record 45 of Set 82 | felanitx
# Processing Record 46 of Set 82 | marsa matruh
# Processing Record 47 of Set 82 | barra da estiva
# Processing Record 48 of Set 82 | bubaque
# Processing Record 49 of Set 82 | salvador
# Processing Record 50 of Set 82 | kensington
# Processing Record 1 of Set 83 | barahona
# Processing Record 2 of Set 83 | ayr
# Processing Record 3 of Set 83 | chegdomyn
# Processing Record 4 of Set 83 | betsiamites
# Processing Record 5 of Set 83 | luganville
# Processing Record 6 of Set 83 | homer
# Processing Record 7 of Set 83 | cilegon
# Processing Record 8 of Set 83 | tual
# Processing Record 9 of Set 83 | kollumerland
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 83 | idah
# Processing Record 11 of Set 83 | santo antonio do ica
# Processing Record 12 of Set 83 | sakaraha
# Processing Record 13 of Set 83 | manavgat
# Processing Record 14 of Set 83 | saryshagan
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 83 | mataram
# Processing Record 16 of Set 83 | westport
# Processing Record 17 of Set 83 | zeya
# Processing Record 18 of Set 83 | vagur
# Processing Record 19 of Set 83 | jiayuguan
# Processing Record 20 of Set 83 | emerald
# Processing Record 21 of Set 83 | bryan
# Processing Record 22 of Set 83 | hunchun
# Processing Record 23 of Set 83 | anito
# Processing Record 24 of Set 83 | inuvik
# Processing Record 25 of Set 83 | mehamn
# Processing Record 26 of Set 83 | inhambane
# Processing Record 27 of Set 83 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 83 | muros
# Processing Record 29 of Set 83 | chicama
# Processing Record 30 of Set 83 | intipuca
# Processing Record 31 of Set 83 | beloostrov
# Processing Record 32 of Set 83 | sao joao da barra
# Processing Record 33 of Set 83 | ouadda
# Processing Record 34 of Set 83 | polson
# Processing Record 35 of Set 83 | machinga
# Processing Record 36 of Set 83 | olinda
# Processing Record 37 of Set 83 | soto la marina
# Processing Record 38 of Set 83 | bababe
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 83 | coihaique
# Processing Record 40 of Set 83 | lushunkou
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 83 | nizwa
# Processing Record 42 of Set 83 | kupang
# Processing Record 43 of Set 83 | nalut
# Processing Record 44 of Set 83 | mlonggo
# Processing Record 45 of Set 83 | cusuna
# Processing Record 46 of Set 83 | moose factory
# Processing Record 47 of Set 83 | kanniyakumari
# Processing Record 48 of Set 83 | kerman
# Processing Record 49 of Set 83 | trincomalee
# Processing Record 50 of Set 83 | koboko
# Processing Record 1 of Set 84 | yatou
# Processing Record 2 of Set 84 | kaka
# Processing Record 3 of Set 84 | juneau
# Processing Record 4 of Set 84 | eenhana
# Processing Record 5 of Set 84 | motygino
# Processing Record 6 of Set 84 | tashigang
# Processing Record 7 of Set 84 | karamea
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 84 | saint-augustin
# Processing Record 9 of Set 84 | straumen
# Processing Record 10 of Set 84 | abu samrah
# Processing Record 11 of Set 84 | kintampo
# Processing Record 12 of Set 84 | lethem
# Processing Record 13 of Set 84 | miranda
# Processing Record 14 of Set 84 | erenhot
# Processing Record 15 of Set 84 | krasnoselkup
# Processing Record 16 of Set 84 | majene
# Processing Record 17 of Set 84 | tilichiki
# Processing Record 18 of Set 84 | romitan
# Processing Record 19 of Set 84 | kamaishi
# Processing Record 20 of Set 84 | port macquarie
# Processing Record 21 of Set 84 | saint anthony
# Processing Record 22 of Set 84 | adrar
# Processing Record 23 of Set 84 | goure
# Processing Record 24 of Set 84 | karpathos
# Processing Record 25 of Set 84 | orange cove
# Processing Record 26 of Set 84 | faya
# Processing Record 27 of Set 84 | camocim
# Processing Record 28 of Set 84 | rafai
# Processing Record 29 of Set 84 | tulun
# Processing Record 30 of Set 84 | grand-lahou
# Processing Record 31 of Set 84 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 84 | praia da vitoria
# Processing Record 33 of Set 84 | ayan
# Processing Record 34 of Set 84 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 84 | windhoek
# Processing Record 36 of Set 84 | alindao
# Processing Record 37 of Set 84 | kahului
# Processing Record 38 of Set 84 | mareeba
# Processing Record 39 of Set 84 | padilla
# Processing Record 40 of Set 84 | malwan
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 84 | lengshuitan
# Processing Record 42 of Set 84 | dauphin
# Processing Record 43 of Set 84 | gore
# Processing Record 44 of Set 84 | tugulym
# Processing Record 45 of Set 84 | sola
# Processing Record 46 of Set 84 | mallaig
# Processing Record 47 of Set 84 | alta floresta
# Processing Record 48 of Set 84 | hailun
# Processing Record 49 of Set 84 | vyartsilya
# Processing Record 50 of Set 84 | makakilo city
# Processing Record 1 of Set 85 | dingle
# Processing Record 2 of Set 85 | dharchula
# Processing Record 3 of Set 85 | samana
# Processing Record 4 of Set 85 | ye
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 85 | sisimiut
# Processing Record 6 of Set 85 | palu
# Processing Record 7 of Set 85 | karauli
# Processing Record 8 of Set 85 | warrington
# Processing Record 9 of Set 85 | high level
# Processing Record 10 of Set 85 | marsaxlokk
# Processing Record 11 of Set 85 | manali
# Processing Record 12 of Set 85 | bridlington
# Processing Record 13 of Set 85 | byumba
# Processing Record 14 of Set 85 | bouna
# Processing Record 15 of Set 85 | chernyshevskiy
# Processing Record 16 of Set 85 | xiongshi
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 85 | leopold
# Processing Record 18 of Set 85 | cape girardeau
# Processing Record 19 of Set 85 | bandarbeyla
# Processing Record 20 of Set 85 | mayskiy
# Processing Record 21 of Set 85 | maraba
# Processing Record 22 of Set 85 | carballo
# Processing Record 23 of Set 85 | robertsport
# Processing Record 24 of Set 85 | safwah
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 85 | sao jose da coroa grande
# Processing Record 26 of Set 85 | qianan
# Processing Record 27 of Set 85 | bilibino
# Processing Record 28 of Set 85 | pathein
# Processing Record 29 of Set 85 | verkhnevilyuysk
# Processing Record 30 of Set 85 | codrington
# Processing Record 31 of Set 85 | eldikan
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 85 | ryotsu
# Processing Record 33 of Set 85 | araouane
# Processing Record 34 of Set 85 | porbandar
# Processing Record 35 of Set 85 | mosetse
# Processing Record 36 of Set 85 | taungdwingyi
# Processing Record 37 of Set 85 | ixtapa
# Processing Record 38 of Set 85 | semnan
# Processing Record 39 of Set 85 | corinto
# Processing Record 40 of Set 85 | farmington
# Processing Record 41 of Set 85 | monforte de lemos
# Processing Record 42 of Set 85 | ouallam
# Processing Record 43 of Set 85 | takoradi
# Processing Record 44 of Set 85 | parainen
# Processing Record 45 of Set 85 | san policarpo
# Processing Record 46 of Set 85 | luena
# Processing Record 47 of Set 85 | weihe
# Processing Record 48 of Set 85 | turka
# Processing Record 49 of Set 85 | caraballeda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 2768

# %%
# convert the list of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0         Pisco      PE  2020-11-08 22:08:04 -13.70  -76.22     68.00
# 1        Katobu      ID  2020-11-08 22:08:05  -4.94  122.53     76.41
# 2  Constitucion      CL  2020-11-08 22:03:25 -35.33  -72.42     62.60
# 3  Ponta Do Sol      PT  2020-11-08 22:08:05  32.67  -17.10     66.20
# 4       Labuhan      ID  2020-11-08 22:08:05  -6.88  112.21     78.66
# 5  Puerto Ayora      EC  2020-11-08 22:08:05  -0.74  -90.35     77.00
# 6     Saskylakh      RU  2020-11-08 22:08:05  71.92  114.08     -9.20
# 7         Moree      AU  2020-11-08 22:08:06 -29.47  149.85     66.20
# 8    Kaitangata      NZ  2020-11-08 22:08:06 -46.28  169.85     53.01
# 9      Penzance      GB  2020-11-08 22:08:06  50.12   -5.54     57.20
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        72           0       25.28                 NaN
# 1        83          92        1.07                 NaN
# 2        58          46       12.41                 NaN
# 3        59          20       10.29                 NaN
# 4        78          94       10.36                 NaN
# 5        69          20       14.99                 NaN
# 6        86           2       13.80                 NaN
# 7        48           9       11.41                 NaN
# 8        81          93        8.01                 NaN
# 9        93          76       20.80                 NaN

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
